# %%
# !nvidia-smi
# Out:
# Wed Dec 10 15:04:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.29                 Driver Version: 581.29         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  |   00000000:07:00.0  On |                  N/A |
# | 43%   33C    P8             21W /  160W |    1863MiB /   6144MiB |     21%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3088    C+G   D:\Feishu\app\Feishu.exe              N/A      |
# |    0   N/A  N/A            6900    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10452    C+G   ...\common\BongoCat\BongoCat.exe      N/A      |
# |    0   N/A  N/A           11988    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           12956    C+G   ...lpaper_engine\wallpaper32.exe      N/A      |
# |    0   N/A  N/A           13584    C+G   ...acted\runtime\WeChatAppEx.exe      N/A      |
# |    0   N/A  N/A           13860    C+G   ...h_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A           15268    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           15488    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           15796    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16592    C+G   ...lus\logioptionsplus_agent.exe      N/A      |
# |    0   N/A  N/A           18032    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           18336    C+G   ...em_tray\lghub_system_tray.exe      N/A      |
# |    0   N/A  N/A           18384    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           18436    C+G   ...crosoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           19332    C+G   ....0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           22328    C+G   ...ffice6\promecefpluginhost.exe      N/A      |
# |    0   N/A  N/A           22408    C+G   ...logioptionsplus_logivoice.exe      N/A      |
# |    0   N/A  N/A           25820    C+G   E:\tabby\Tabby.exe                    N/A      |
# |    0   N/A  N/A           26652    C+G   ...10.28554.205\QQPCExternal.exe      N/A      |
# |    0   N/A  N/A           45364    C+G   ... 2025.1.1.1\bin\pycharm64.exe      N/A      |
# |    0   N/A  N/A           51648    C+G   C:\Windows\System32\svchost.exe       N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
from torch import nn

torch.device('cpu'), torch.device('cuda'), torch.device('cuda:0')
# Out:
# (device(type='cpu'), device(type='cuda'), device(type='cuda', index=0))

# %%
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Build Version: {torch.version.cuda}")
# Out:
# PyTorch Version: 2.5.1
# CUDA Build Version: 12.1

# %%
x = torch.tensor([1, 2, 3])
x.device
# Out:
# device(type='cpu')

# %%
y = x.to(device='cuda:0')
y
# Out:
# tensor([1, 2, 3], device='cuda:0')

# %%
y.device
# Out:
# device(type='cuda', index=0)
