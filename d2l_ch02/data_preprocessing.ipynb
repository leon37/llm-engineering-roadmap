# %%
import pandas as pd

# %%
import os

os.makedirs(os.path.join('..', 'data'), exist_ok=True)
data_file = os.path.join('..', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,NanTest,Price\n')  # 列名
    f.write('NA,Pave,NA,127500\n')  # 每行表示一个数据样本
    f.write('2,NA,NA,106000\n')
    f.write('4,NA,NA,178100\n')
    f.write('NA,NA,NA,140000\n')

# %%
data = pd.read_csv(data_file)
# Out:
# 4

# %%
inputs, outputs = data.iloc[:, 0:3], data.iloc[:, 3]
inputs = inputs.fillna(inputs.mean())
print(inputs)
# Out:
#    NumRooms Alley  NanTest
# 0       3.0  Pave      NaN
# 1       2.0   NaN      NaN
# 2       4.0   NaN      NaN
# 3       3.0   NaN      NaN

# %%
inputs = pd.get_dummies(inputs, dummy_na=True)

nan_counts = inputs.isna().sum()
inputs_cleaned = inputs.loc[:, nan_counts < nan_counts.max()]
# inputs.dropna(axis=1, thresh=inputs.isna().sum().max())

# %%
import torch
X = torch.tensor(inputs.to_numpy(dtype=float))
y = torch.tensor(outputs.to_numpy(dtype=float))
X, y
# Out:
# (tensor([[3., nan, 1., 0.],
#          [2., nan, 0., 1.],
#          [4., nan, 0., 1.],
#          [3., nan, 0., 1.]], dtype=torch.float64),
#  tensor([127500., 106000., 178100., 140000.], dtype=torch.float64))
